# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\deepa\OneDrive\Documents\amex\amex_r1\data\dataset.csv")

# %%
# Ensure df exists and f17 is present before creating the indicator column
if 'df' in globals():
    if "f17" in df.columns:
        df["f17_missing"] = df["f17"].isna().astype(int)
    else:
        raise KeyError("Column 'f17' not found in df. Check dataframe columns.")
else:
    raise NameError("df is not defined. Load or define df in a prior cell before running this cell.")
